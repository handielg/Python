# %% [markdown]
# <a href="https://colab.research.google.com/github/handielg/Python/blob/main/yfinance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #yfinance

# %% [markdown]
# `yfinance` tiene como objetivo ofrecer una manera confiable de descargar datos históricos del mercado de finanzas desde Yahoo Finance!

# %%
# !pip install yfinance
# Out:
# ...
#      |████████████████████████████████| 5.5MB 3.5MB/s
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.55-py2.py3-none-any.whl size=22618 sha256=d2f91b44e934b7ec098f096572ffe60f74edde51214a6bca9fa39c28600e2c74
#   Stored in directory: /root/.cache/pip/wheels/04/98/cc/2702a4242d60bdc14f48b4557c427ded1fe92aedf257d4565c
# Successfully built yfinance
# ...
#   Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ...

# %%
import yfinance as yf

# %% [markdown]
# Ejemplos:

# %%
TK = yf.Ticker("MSFT") #definimos TK con el nombre del ticker introducido.

# %%
# Obtener información de la empresa.
TK.info
# Out:
# {'52WeekChange': 0.59857357,
#  'SandP52WeekChange': 0.16647923,
#  'address1': 'One Microsoft Way',
#  'algorithm': None,
#  'annualHoldingsTurnover': None,
#  'annualReportExpenseRatio': None,
#  'ask': 220.07,
#  'askSize': 1000,
#  'averageDailyVolume10Day': 27025187,
#  'averageVolume': 33866804,
#  'averageVolume10days': 27025187,
#  'beta': 0.923331,
#  'beta3Year': None,
#  'bid': 0,
#  'bidSize': 800,
#  'bookValue': 15.626,
#  'category': None,
#  'circulatingSupply': None,
#  'city': 'Redmond',
#  'companyOfficers': [],
#  'country': 'United States',
#  'currency': 'USD',
#  'dateShortInterest': 1601424000,
#  'dayHigh': 220.35,
#  'dayLow': 216.01,
#  'dividendRate': 2.24,
#  'dividendYield': 0.010199999,
#  'earningsQuarterlyGrowth': -0.151,
#  'enterpriseToEbitda': 24.639,
#  'enterpriseToRevenue': 11.243,
#  'enterpriseValue': 1607928643584,
#  'exDividendDate': 1605657600,
#  'exchange': 'NMS',
#  'exchangeTimezoneName': 'America/New_York',
# ...

# %%
# Obtener datos históricos de mercado.
hist = TK.history(period="max")
hist
# Out:
#                   Open        High  ...  Dividends  Stock Splits
# Date                                ...
# 1986-03-13    0.056514    0.064825  ...        0.0           0.0
# 1986-03-14    0.062055    0.065379  ...        0.0           0.0
# 1986-03-17    0.064271    0.065933  ...        0.0           0.0
# 1986-03-18    0.065379    0.065933  ...        0.0           0.0
# 1986-03-19    0.063717    0.064271  ...        0.0           0.0
# ...                ...         ...  ...        ...           ...
# 2020-10-09  211.229996  215.860001  ...        0.0           0.0
# 2020-10-12  218.789993  223.860001  ...        0.0           0.0
# 2020-10-13  222.720001  225.210007  ...        0.0           0.0
# 2020-10-14  223.000000  224.220001  ...        0.0           0.0
# 2020-10-15  217.100006  220.360001  ...        0.0           0.0
#
# [8721 rows x 7 columns]

# %%
#para descragar precios de múltiples acciones hacemos lo siguiente.
tickers = ["MSFT", "AAPL", "GOOG"] #creamos una lista con todos los tickers que queremos.
data = yf.download(tickers, start="2020-10-10", end="2020-10-16", group_by='column', interval = "1m")  #viene group_by='column' por defecto. A intervalos de 1 minuto.
data
# Out:
# [*********************100%***********************]  3 of 3 completed
#                             Adj Close               ...   Volume
#                                  AAPL         GOOG  ...     GOOG     MSFT
# Datetime                                            ...
# 2020-10-12 09:30:00-04:00  119.575203  1539.845825  ...  69616.0  1426929
# 2020-10-12 09:31:00-04:00  119.690002  1536.729980  ...  14506.0   255290
# 2020-10-12 09:32:00-04:00  119.860001  1536.000000  ...  10699.0   183313
# 2020-10-12 09:33:00-04:00  120.000000  1534.160034  ...  10674.0   194819
# 2020-10-12 09:34:00-04:00  120.239998  1538.530029  ...  15981.0   147195
# ...                               ...          ...  ...      ...      ...
# 2020-10-15 15:55:00-04:00  120.766197  1558.145020  ...   9958.0   159252
# 2020-10-15 15:56:00-04:00  120.800003  1558.844971  ...   5401.0   148707
# 2020-10-15 15:57:00-04:00  120.699997  1558.219971  ...  16569.0   157638
# ...

# %%
# Mostrar las veces que se hicieron Stock splits y se repartió dividendos.
TK.actions
# Out:
#             Dividends  Stock Splits
# Date
# 1987-09-21       0.00           2.0
# 1990-04-16       0.00           2.0
# 1991-06-27       0.00           1.5
# 1992-06-15       0.00           1.5
# 1994-05-23       0.00           2.0
# ...               ...           ...
# 2019-08-14       0.46           0.0
# 2019-11-20       0.51           0.0
# 2020-02-19       0.51           0.0
# 2020-05-20       0.51           0.0
# 2020-08-19       0.51           0.0
#
# [76 rows x 2 columns]

# %%
# Muestra los dividendos repartidos.
TK.dividends
# Out:
# Date
# 2003-02-19    0.08
# 2003-10-15    0.16
# 2004-08-23    0.08
# 2004-11-15    3.08
# 2005-02-15    0.08
#               ...
# 2019-08-14    0.46
# 2019-11-20    0.51
# 2020-02-19    0.51
# 2020-05-20    0.51
# 2020-08-19    0.51
# Name: Dividends, Length: 67, dtype: float64

# %%
# show financials NO FUNCIONA
TK.financials

# %%
msft.quarterly_financials #NO FUNCIONA

# %%
# muestra a los principales titulares
TK.major_holders
# Out:
#         0                                      1
# 0   1.42%        % of Shares Held by All Insider
# 1  74.09%       % of Shares Held by Institutions
# 2  75.16%        % of Float Held by Institutions
# 3    4630  Number of Institutions Holding Shares

# %%
 # muestra a los titulares institucionales
TK.institutional_holders
# Out:
#                               Holder     Shares  ...   % Out         Value
# 0         Vanguard Group, Inc. (The)  632013255  ...  0.0835  128621017525
# 1                     Blackrock Inc.  521841633  ...  0.0690  106199990731
# 2           State Street Corporation  314554694  ...  0.0416   64015025775
# 3                           FMR, LLC  236873992  ...  0.0313   48206226111
# 4      Price (T.Rowe) Associates Inc  183090016  ...  0.0242   37260649156
# 5            Capital World Investors  122923512  ...  0.0162   25016163927
# 6      Geode Capital Management, LLC  116688974  ...  0.0154   23747373098
# 7    Capital International Investors   98209725  ...  0.0130   19986661134
# 8  Capital Research Global Investors   94081197  ...  0.0124   19146464401
# 9         Northern Trust Corporation   93331898  ...  0.0123   18993974561
#
# [10 rows x 5 columns]

# %%
# show balance sheet. NO FUNCIONA
msft.balance_sheet
msft.quarterly_balance_sheet

# %%
# show cashflow NO FUNCIONA
TK.cashflow
TK.quarterly_cashflow

# %%
# show earnings NO FUNCIONA
#TK.earnings
TK.quarterly_earnings

# %%
# Muestra la sostenibilidad de la empresa.
TK.sustainability
# Out:
#                                      Value
# 2020-10
# palmOil                              False
# controversialWeapons                 False
# gambling                             False
# socialScore                           9.37
# nuclear                              False
# furLeather                           False
# alcoholic                            False
# gmo                                  False
# catholic                             False
# socialPercentile                      None
# peerCount                              103
# governanceScore                       5.09
# environmentPercentile                 None
# animalTesting                        False
# tobacco                              False
# totalEsg                             14.94
# highestControversy                       3
# esgPerformance                  UNDER_PERF
# coal                                 False
# pesticides                           False
# adult                                False
# ...

# %%
# muestra las recomendaciones de diferentes analistas.
TK.recommendations
# Out:
#                                Firm       To Grade  From Grade Action
# Date
# 2012-03-16 08:19:00  Argus Research            Buy                 up
# 2012-03-19 14:00:00  Hilliard Lyons  Long-Term Buy               main
# 2012-03-22 07:03:00  Morgan Stanley     Overweight               main
# 2012-04-03 11:53:00             UBS            Buy               main
# 2012-04-20 06:18:00   Deutsche Bank            Buy               main
# ...                             ...            ...         ...    ...
# 2020-07-20 14:48:02   Raymond James     Strong Buy               main
# 2020-07-23 08:43:04   Piper Sandler     Overweight               main
# 2020-07-23 13:06:12     Oppenheimer        Perform  Outperform   down
# 2020-09-09 12:01:51  Morgan Stanley     Overweight               main
# 2020-10-13 16:40:00     RBC Capital     Outperform               main
#
# [281 rows x 4 columns]

# %%
# muestra el calendario de su próxima presentación (earnings, etc)
TK.calendar
# Out:
#                                 Value
# Earnings Date     2020-10-27 00:00:00
# Earnings Average                 1.54
# Earnings Low                     1.49
# Earnings High                    1.61
# Revenue Average           35720400000
# Revenue Low               35299100000
# Revenue High              36394000000

# %%
# Muestra el ISIN de la empresa (ISIN = International Securities Identification Number).
TK.isin
# Out:
# 'US5949181045'

# %%
# muestra las fechas en que expiran las opciones.
TK.options
# Out:
# ('2020-10-16',
#  '2020-10-23',
#  '2020-10-30',
#  '2020-11-06',
#  '2020-11-13',
#  '2020-11-20',
#  '2020-11-27',
#  '2020-12-18',
#  '2021-01-15',
#  '2021-02-19',
#  '2021-03-19',
#  '2021-04-16',
#  '2021-06-18',
#  '2021-07-16',
#  '2021-09-17',
#  '2022-01-21',
#  '2022-03-18',
#  '2022-06-17',
#  '2022-09-16',
#  '2023-01-20')

# %%
# obtener la lista de opciones para una expiración específica
opt = TK.option_chain('2020-10-16')
# data available via: opt.calls, opt.puts
opt
# Out:
# Options(calls=         contractSymbol       lastTradeDate  ...  contractSize  currency
# 0   MSFT201016C00080000 2020-10-15 13:39:44  ...       REGULAR       USD
# 1   MSFT201016C00085000 2020-10-15 19:41:12  ...       REGULAR       USD
# 2   MSFT201016C00090000 2020-10-12 14:02:59  ...       REGULAR       USD
# 3   MSFT201016C00095000 2020-10-05 19:39:25  ...       REGULAR       USD
# 4   MSFT201016C00100000 2020-10-02 14:57:54  ...       REGULAR       USD
# 5   MSFT201016C00105000 2020-10-05 19:39:25  ...       REGULAR       USD
# 6   MSFT201016C00110000 2020-10-07 17:44:51  ...       REGULAR       USD
# 7   MSFT201016C00115000 2020-10-12 19:58:37  ...       REGULAR       USD
# 8   MSFT201016C00120000 2020-10-15 19:41:44  ...       REGULAR       USD
# 9   MSFT201016C00125000 2020-10-15 16:17:13  ...       REGULAR       USD
# 10  MSFT201016C00130000 2020-10-07 13:44:33  ...       REGULAR       USD
# 11  MSFT201016C00135000 2020-10-12 19:59:03  ...       REGULAR       USD
# ...

# %%
# Muestra los splits realizados.
TK.splits
# Out:
# Date
# 1987-09-21    2.0
# 1990-04-16    2.0
# 1991-06-27    1.5
# 1992-06-15    1.5
# 1994-05-23    2.0
# 1996-12-09    2.0
# 1998-02-23    2.0
# 1999-03-29    2.0
# 2003-02-18    2.0
# Name: Stock Splits, dtype: float64

# %%
data = yf.download(  # or pdr.get_data_yahoo(...
        # tickers list or string as well
        tickers = "AAPL", "MSFT",

        # podemos usar "period" en vez de start/end
        # periodos válidos: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
        # (opcional, por defecto es '1mo')
        period = "ytd",

        # recuperar datos por intervalo (incluido intradía si el período es <60 días)
        # intervalos válidos: 1m, 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo
        # (opcional, por defecto es '1d')
        interval = "1m",

        # agrupar por ticker (para acceder a través de datos ['SPY'])
        # (opcional, por defecto es 'column')
        group_by = 'ticker',

        # ajustar todos los OHLC automáticamente
        # (opcional, por defecto es False)
        auto_adjust = True,

        # descargar datos previos / posteriores al horario habitual del mercado
        # (opcional, por defecto es False)
        prepost = True,

        # usar hilos para descargas masivas? (True/False/Integer)
        # (opcional, por defecto es True)
        threads = True,

        # proxy URL, uso del esquema uso al descargar?
        # (opcional, por defecto es None)
        proxy = None
    )
