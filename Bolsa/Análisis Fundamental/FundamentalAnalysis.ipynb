# %% [markdown]
# <a href="https://colab.research.google.com/github/handielg/Python/blob/main/Bolsa/An%C3%A1lisis%20Fundamental/FundamentalAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #FundamentalAnalysis

# %% [markdown]
# Este paquete recopila fundamentos y datos detallados de las acciones de la compañía de un gran grupo de empresas (13.000+) de FinancialModelingPrep y utiliza Yahoo Finance para obtener datos de acciones para cualquier instrumento financiero. Permite al usuario realizar la mayor parte del análisis fundamental esencial. También ofrece la posibilidad de comparar rápidamente varias empresas o hacer un análisis sectorial.
#
# Vea una visualización de los datos en mi sitio web de [Fundamentals Quantifier](https://fundamentals-quantifier.herokuapp.com/).

# %% [markdown]
# Aquí puede encontrar una lista de las funciones disponibles dentro de este paquete separado por módulo.
#
# **Detalles:**
#
# - `available companies` - muestra la lista completa de empresas que están disponibles para la recopilación de datos fundamentales, incluyendo el precio actual y el intercambio en el que cotiza la empresa. Esta es una extensa lista con más de 13.000 empresas.
#
# - `profile` - proporciona información sobre, entre otras cosas, la industria, el intercambio sectorial y la descripción de la empresa.
#
# - `quote` - proporciona información real sobre la empresa que es, entre otras cosas, el día alto, capitalización de mercado, precio de apertura y cierre y relación precio-equity.
#
# - `enterprise` - muestra el precio de las acciones, el número de acciones, la capitalización de mercado y el valor de la empresa a lo largo del tiempo.
#
# - `rating` - sobre la base de ratios específicos, proporciona información sobre si la empresa es una compra (fuerte), neutral o una venta (fuerte).
# discounted_cash_flow - calcula el flujo de caja descontado de una empresa a lo largo del tiempo, incluido el DCF de hoy.
#
# - `earnings_calendar` - muestra información sobre la fecha de ganancias de una gran selección de símbolos este año, incluida la relación de PE esperada.
# financial_statement
#
# - `income_statement` - cobra una cuenta de resultados completa a lo largo del tiempo. Esto puede ser trimestral o anual.
#
# - `balance_sheet_statement` - recopila un estado de balance completo a lo largo del tiempo. Esto puede ser trimestral o anual.
#
# - `cash_flow_statement` - recoge un estado de flujo de efectivo completo a lo largo del tiempo. Esto puede ser trimestral o anual.
#
# **Ratios**
#
# - `key_metrics` - enumera las métricas clave (en total 57 métricas) de una empresa a lo largo del tiempo (anual y trimestral). Esto incluye, entre otras cosas, el retorno de la equidad (ROE), el capital de trabajo, la relación actual y la deuda a los activos.
#
# - `financial_ratios` - incluye ratios en profundidad (en total 57 ratios) de una empresa a lo largo del tiempo (anual y trimestral). Esto contiene, entre otras cosas, relación precio-libro, relación de pago y ciclo operativo.
#
# - `financial_statement_growth` - mide el crecimiento de varias partidas y ratios de los estados financieros a lo largo del tiempo (anuales y trimestrales). Estos son, entre otras cosas, El Crecimiento de los Ingresos (3, 5 y 10 años), el crecimiento del inventario y el crecimiento del flujo de caja operativo (3, 5 y 10 años).
#
# **Stock_data**
#
# - `stock_data` - recopila todos los datos de stock (incluyendo Cerrar, Cierre Ajustado, Alto, Bajo, Abrir y Volumen) del ticker proporcionado. Puede ser cualquier instrumento financiero.
#
# - `stock_data_detailed` - recopila una cantidad amplia de datos de stock (incluyendo Cerrar, Cierre Ajustado, Alto, Bajo, Abrir, Volumen, Volumen No Ajustado, Cambio Absoluto, Cambio porcentual, Precio Promedio Ponderado por Volumen (VWAP), Etiqueta de Fecha y Cambio a lo largo del Tiempo). La recopilación de datos se limita a las empresas enumeradas en la función `available companies`. Utilice la función  `stock_data` para obtener información sobre cualquier otra cosa. (ETFs, Fondos Mutuos, Opciones, Indices, etc.)

# %% [markdown]
# Para instalar el paquete ejecutamos lo siguiente:

# %%
# !pip install FundamentalAnalysis
# Out:
# Collecting FundamentalAnalysis
#   Downloading https://files.pythonhosted.org/packages/46/dc/e406176367089af57e0e2ec2043b4e2bf81cc9cd1184f51e4a0de5a1296b/FundamentalAnalysis-0.2.6.tar.gz
# Building wheels for collected packages: FundamentalAnalysis
#   Building wheel for FundamentalAnalysis (setup.py) ... done
#   Created wheel for FundamentalAnalysis: filename=FundamentalAnalysis-0.2.6-cp36-none-any.whl size=9734 sha256=a89de0f0d7d91b234a50680c7f865cf67573a4972dc6a5171770ab0247c7f344
#   Stored in directory: /root/.cache/pip/wheels/d2/09/b7/cae273de32fdaa5dae02f207e91294b40fd1cba026448116a3
# Successfully built FundamentalAnalysis
# Installing collected packages: FundamentalAnalysis
# Successfully installed FundamentalAnalysis-0.2.6

# %% [markdown]
# Para importar el módulo hacemos lo siguiente:

# %%
import FundamentalAnalysis as fa

# %% [markdown]
# Ejemplos:

# %%
ticker = "AAPL"
api_key = "687b97024fe6079bc873f4087ad41e2b"

# %%
# Mostrar las compañías disponibles.
companies = fa.available_companies(api_key)
companies
# Out:
#                             name    price                 exchange
# symbol
# SPY                 SPDR S&P 500  349.560                NYSE Arca
# CMCSA               Comcast Corp   45.450     Nasdaq Global Select
# KMI            Kinder Morgan Inc   13.055  New York Stock Exchange
# INTC                  Intel Corp   54.384     Nasdaq Global Select
# MU         Micron Technology Inc   52.450     Nasdaq Global Select
# ...                          ...      ...                      ...
# TIETOO.OL         TietoEVRY Corp  266.600                      OSE
# BWE.OL             BW Energy Ltd   17.600                      OSE
# NOL.OL        Northern Ocean Ltd    6.120                      OSE
# PEXIP.OL       Pexip Holding ASA   82.000                      OSE
# KDNY           Aduro Biotech Inc   16.540     Nasdaq Global Select
#
# [26467 rows x 3 columns]

# %%
# Recopilar información general de la empresa.
profile = fa.profile(ticker, api_key)
profile
# Out:
#                                                                    0
# symbol                                                          AAPL
# price                                                        119.598
# beta                                                         1.33701
# volAvg                                                     173037703
# mktCap                                                 2045428110000
# lastDiv                                                       0.7825
# range                                                 53.1525-137.98
# changes                                                      -1.1118
# companyName                                                Apple Inc
# currency                                                         USD
# cik                                                       0000320193
# isin                                                    US0378331005
# cusip                                                      037833100
# exchange                                        Nasdaq Global Select
# exchangeShortName                                             NASDAQ
# industry                                        Consumer Electronics
# website                                       https://www.apple.com/
# description        Apple, Inc. engages in the design, manufacture...
# ceo                                                 Mr. Timothy Cook
# sector                                                    Technology
# country                                                           US
# fullTimeEmployees                                             137000
# phone                                                    14089961010
# address                                             1 Apple Park Way
# city                                                       Cupertino
# state                                                     CALIFORNIA
# zip                                                            95014
# dcfDiff                                                        89.92
# dcf                                                          131.217
# image              https://financialmodelingprep.com/image-stock/...
# ipoDate                                                   1980-12-12
# defaultImage                                                   False

# %%
# Recopilar cotizaciones recientes de la empresa.
quotes = fa.quote(ticker, api_key)
quotes
# Out:
#                                                  0
# symbol                                        AAPL
# name                                    Apple Inc.
# price                                      119.709
# changesPercentage                            -0.83
# change                                     -1.0007
# dayLow                                      119.46
# dayHigh                                     121.54
# yearHigh                                    137.98
# yearLow                                    53.1525
# marketCap                              2.04733e+12
# priceAvg50                                 116.868
# priceAvg200                                94.9031
# volume                                    55220049
# avgVolume                                173037703
# exchange                                    NASDAQ
# open                                        121.28
# previousClose                               120.71
# eps                                          3.296
# pe                                         36.3196
# earningsAnnouncement  2020-10-29T20:00:00.000+0000
# sharesOutstanding                      17102499605
# timestamp                               1602864480

# %%
# Obtener market cap (MC) y enterprise value (EV)
entreprise_value = fa.enterprise(ticker, api_key)
entreprise_value
# Out:
#                                     2019  ...         1983
# symbol                              AAPL  ...         AAPL
# stockPrice                       62.2625  ...     0.093192
# numberOfShares               18595652000  ...  13412000000
# marketCapitalization         1.15781e+12  ...   1249891104
# minusCashAndCashEquivalents  48844000000  ...    143000000
# addTotalDebt                 97787000000  ...        1e+06
# enterpriseValue              1.20675e+12  ...   1107891104
#
# [7 rows x 37 columns]

# %%
# Mostrar recomendaciones de analistas.
ratings = fa.rating(ticker, api_key)
ratings
# Out:
#     score recommendation
# P/B     5     Strong Buy
# ROA     5            Buy
# DCF     4            Buy
# P/E     5     Strong Buy
# ROE     5     Strong Buy
# D/E     4     Strong Buy

# %%
# Obtener DCFs (Discounted Cash Flow) en el tiempo
dcf_annually = fa.discounted_cash_flow(ticker, api_key, period="annual")
dcf_annually
# Out:
#                    2020        2019  ...        2010        2009
# date         2020-10-16  2019-09-28  ...  2010-09-25  2009-09-26
# Stock Price     119.765     62.2625  ...       11.03     7.23143
# DCF             130.272     72.8398  ...     23.4121     10.9733
#
# [3 rows x 12 columns]

# %%
#ahora lo calculamos trimestral.
dcf_quarterly = fa.discounted_cash_flow(ticker, api_key, period="quarter")
dcf_quarterly
# Out:
#                 2020-10     2020-06  ...     2009-09     2009-06
# date         2020-10-16  2020-06-27  ...  2009-09-26  2009-06-27
# Stock Price     119.765       94.81  ...     7.23143     5.71786
# DCF             130.272     102.462  ...     10.9733     9.58967
#
# [3 rows x 46 columns]

# %%
# Obtener el balance.
balance_sheet_annually = fa.balance_sheet_statement(ticker, api_key, period="annual")
balance_sheet_annually
# Out:
#                                                                                       2019  ...        1983
# fillingDate                                                            2019-10-31 00:00:00  ...        None
# acceptedDate                                                           2019-10-30 18:12:36  ...        None
# period                                                                                  FY  ...          FY
# cashAndCashEquivalents                                                         48844000000  ...   143000000
# shortTermInvestments                                                           51713000000  ...           0
# cashAndShortTermInvestments                                                   100557000000  ...   143000000
# netReceivables                                                                 45804000000  ...   136000000
# inventory                                                                       4106000000  ...   142000000
# otherCurrentAssets                                                             12352000000  ...    48000000
# totalCurrentAssets                                                            162819000000  ...   469000000
# propertyPlantEquipmentNet                                                      37378000000  ...    67000000
# goodwill                                                                                 0  ...           0
# intangibleAssets                                                                         0  ...           0
# goodwillAndIntangibleAssets                                                              0  ...           0
# longTermInvestments                                                           105341000000  ...           0
# taxAssets                                                                                0  ...    49000000
# otherNonCurrentAssets                                                          32978000000  ...    21000000
# totalNonCurrentAssets                                                         175697000000  ...    88000000
# otherAssets                                                                    45330000000  ...    68000000
# totalAssets                                                                   338516000000  ...   557000000
# accountPayables                                                                46236000000  ...    53000000
# shortTermDebt                                                                   5980000000  ...           0
# taxPayables                                                                              0  ...           0
# deferredRevenue                                                                 5522000000  ...           0
# otherCurrentLiabilities                                                        43242000000  ...    39000000
# totalCurrentLiabilities                                                       105718000000  ...   129000000
# longTermDebt                                                                   91807000000  ...       1e+06
# deferredRevenueNonCurrent                                                                0  ...           0
# deferredTaxLiabilitiesNonCurrent                                                         0  ...           0
# otherNonCurrentLiabilities                                                     50503000000  ...           0
# totalNonCurrentLiabilities                                                    142310000000  ...    50000000
# otherLiabilities                                                               50503000000  ...           0
# totalLiabilities                                                              248028000000  ...   179000000
# commonStock                                                                    45174000000  ...   184000000
# retainedEarnings                                                               45898000000  ...   195000000
# accumulatedOtherComprehensiveIncomeLoss                                         -584000000  ...   -43000000
# othertotalStockholdersEquity                                                   -1291000000  ...           0
# totalStockholdersEquity                                                        90488000000  ...   378000000
# totalLiabilitiesAndStockholdersEquity                                         338516000000  ...   557000000
# totalInvestments                                                              157054000000  ...           0
# totalDebt                                                                     108047000000  ...       1e+06
# netDebt                                                                        59203000000  ...  -142000000
# link                                     https://www.sec.gov/Archives/edgar/data/320193...  ...        None
# finalLink                                https://www.sec.gov/Archives/edgar/data/320193...  ...        None
#
# [44 rows x 37 columns]

# %%
#ahora lo calculamos trimestral
balance_sheet_quarterly = fa.balance_sheet_statement(ticker, api_key, period="quarter")
balance_sheet_quarterly
# Out:
#                                                                                    2020-06  ...     1989-09
# fillingDate                                                                     2020-07-31  ...        None
# acceptedDate                                                           2020-07-30 19:29:09  ...        None
# period                                                                                  Q3  ...          Q4
# cashAndCashEquivalents                                                         33383000000  ...   438000000
# shortTermInvestments                                                           59642000000  ...   371000000
# cashAndShortTermInvestments                                                    93025000000  ...   809000000
# netReceivables                                                                 32075000000  ...   793000000
# inventory                                                                       3978000000  ...   475000000
# otherCurrentAssets                                                             10987000000  ...   217000000
# totalCurrentAssets                                                            140065000000  ...  2294000000
# propertyPlantEquipmentNet                                                      43851000000  ...   334000000
# goodwill                                                                                 0  ...           0
# intangibleAssets                                                                         0  ...           0
# goodwillAndIntangibleAssets                                                              0  ...           0
# longTermInvestments                                                           100592000000  ...           0
# taxAssets                                                                                0  ...   363000000
# otherNonCurrentAssets                                                          32836000000  ...   115000000
# totalNonCurrentAssets                                                         177279000000  ...   450000000
# otherAssets                                                                    43823000000  ...   332000000
# totalAssets                                                                   317344000000  ...  2744000000
# accountPayables                                                                35325000000  ...   334000000
# shortTermDebt                                                                  11166000000  ...    57000000
# taxPayables                                                                              0  ...           0
# deferredRevenue                                                                 6313000000  ...           0
# otherCurrentLiabilities                                                        39945000000  ...   231000000
# totalCurrentLiabilities                                                        95318000000  ...   895000000
# longTermDebt                                                                   94678000000  ...           0
# deferredRevenueNonCurrent                                                                0  ...           0
# deferredTaxLiabilitiesNonCurrent                                                         0  ...           0
# otherNonCurrentLiabilities                                                     55066000000  ...           0
# totalNonCurrentLiabilities                                                    149744000000  ...   363000000
# otherLiabilities                                                               55066000000  ...           0
# totalLiabilities                                                              245062000000  ...  1258000000
# commonStock                                                                    48696000000  ...   315000000
# retainedEarnings                                                               24136000000  ...  1176000000
# accumulatedOtherComprehensiveIncomeLoss                                         -550000000  ...  -309000000
# othertotalStockholdersEquity                                                   -2163000000  ...      -2e+06
# totalStockholdersEquity                                                        72282000000  ...  1486000000
# totalLiabilitiesAndStockholdersEquity                                         317344000000  ...  2744000000
# totalInvestments                                                              160234000000  ...   371000000
# totalDebt                                                                     113373000000  ...    57000000
# netDebt                                                                        79990000000  ...  -381000000
# link                                     https://www.sec.gov/Archives/edgar/data/320193...  ...        None
# finalLink                                https://www.sec.gov/Archives/edgar/data/320193...  ...        None
#
# [44 rows x 124 columns]

# %%
# Ontener el Estado de Resultados.
income_statement_annually = fa.income_statement(ticker, api_key, period="annual")
income_statement_annually
# Out:
#                                                                                2019  ...         1983
# fillingDate                                                     2019-10-31 00:00:00  ...         None
# acceptedDate                                                    2019-10-30 18:12:36  ...         None
# period                                                                           FY  ...           FY
# revenue                                                                260174000000  ...    983000000
# costOfRevenue                                                          161782000000  ...    506000000
# grossProfit                                                             98392000000  ...    477000000
# grossProfitRatio                                                           0.378178  ...     0.485249
# researchAndDevelopmentExpenses                                          16217000000  ...     60000000
# generalAndAdministrativeExpenses                                        18245000000  ...    287000000
# sellingAndMarketingExpenses                                                       0  ...            0
# otherExpenses                                                            1807000000  ...            0
# operatingExpenses                                                       34462000000  ...    347000000
# costAndExpenses                                                        196244000000  ...    853000000
# interestExpense                                                          3576000000  ...            0
# depreciationAndAmortization                                             12547000000  ...            0
# ebitda                                                                  81860000000  ...    146000000
# ebitdaratio                                                                0.314636  ...     0.148525
# operatingIncome                                                         63930000000  ...    130000000
# operatingIncomeRatio                                                        0.24572  ...     0.132248
# totalOtherIncomeExpensesNet                                               422000000  ...     16000000
# incomeBeforeTax                                                         65737000000  ...    146000000
# incomeBeforeTaxRatio                                                       0.252666  ...     0.148525
# incomeTaxExpense                                                        10481000000  ...     69000000
# netIncome                                                               55256000000  ...     77000000
# netIncomeRatio                                                             0.212381  ...     0.078332
# eps                                                                         2.97145  ...      0.00574
# epsdiluted                                                                  2.97145  ...      0.00574
# weightedAverageShsOut                                                   18595652000  ...  13412000000
# weightedAverageShsOutDil                                                18595652000  ...  13412000000
# link                              https://www.sec.gov/Archives/edgar/data/320193...  ...         None
# finalLink                         https://www.sec.gov/Archives/edgar/data/320193...  ...         None
#
# [31 rows x 37 columns]

# %%
#ahora lo calculamos trimestralmente.
income_statement_quarterly = fa.income_statement(ticker, api_key, period="quarter")
income_statement_quarterly
# Out:
#                                                                             2020-06  ...      1989-06
# fillingDate                                                              2020-07-31  ...         None
# acceptedDate                                                    2020-07-30 19:29:09  ...         None
# period                                                                           Q3  ...           Q3
# revenue                                                                 59685000000  ...   1248000000
# costOfRevenue                                                           37005000000  ...    631000000
# grossProfit                                                             22680000000  ...    617000000
# grossProfitRatio                                                           0.379995  ...     0.494391
# researchAndDevelopmentExpenses                                           4758000000  ...    103000000
# generalAndAdministrativeExpenses                                         4831000000  ...    363000000
# sellingAndMarketingExpenses                                                       0  ...            0
# otherExpenses                                                              46000000  ...            0
# operatingExpenses                                                        9589000000  ...    467000000
# costAndExpenses                                                         46594000000  ...   1098000000
# interestExpense                                                           697000000  ...            0
# depreciationAndAmortization                                              2752000000  ...     85000000
# ebitda                                                                  16586000000  ...    242000000
# ebitdaratio                                                                0.277892  ...      0.19391
# operatingIncome                                                         13091000000  ...    150000000
# operatingIncomeRatio                                                       0.219335  ...     0.120192
# totalOtherIncomeExpensesNet                                              -158000000  ...        8e+06
# incomeBeforeTax                                                         13137000000  ...    158000000
# incomeBeforeTaxRatio                                                       0.220106  ...     0.126603
# incomeTaxExpense                                                         1884000000  ...     61000000
# netIncome                                                               11253000000  ...     96000000
# netIncomeRatio                                                              0.18854  ...     0.076923
# eps                                                                         0.64601  ...      0.00663
# epsdiluted                                                                  0.64601  ...      0.00663
# weightedAverageShsOut                                                   17419152000  ...  14480000000
# weightedAverageShsOutDil                                                17419152000  ...  14480000000
# link                              https://www.sec.gov/Archives/edgar/data/320193...  ...         None
# finalLink                         https://www.sec.gov/Archives/edgar/data/320193...  ...         None
#
# [31 rows x 125 columns]

# %%
# Obtener el estado de Flujos de Caja.
cash_flow_statement_annually = fa.cash_flow_statement(ticker, api_key, period="annual")
cash_flow_statement_annually
# Out:
#                                                                                        2019  ...       1985
# fillingDate                                                             2019-10-31 00:00:00  ...       None
# acceptedDate                                                            2019-10-30 18:12:36  ...       None
# period                                                                                   FY  ...         FY
# netIncome                                                                       55256000000  ...   61000000
# depreciationAndAmortization                                                     12547000000  ...   42000000
# deferredIncomeTax                                                                -340000000  ...   21000000
# stockBasedCompensation                                                           6068000000  ...          0
# changeInWorkingCapital                                                          -3488000000  ...  128000000
# accountsReceivables                                                               245000000  ...   38000000
# inventory                                                                        -289000000  ...   98000000
# accountsPayables                                                                -1923000000  ...   34000000
# otherWorkingCapital                                                             57101000000  ...          0
# otherNonCashItems                                                                5416000000  ...   13000000
# netCashProvidedByOperatingActivities                                            69391000000  ...  265000000
# investmentsInPropertyPlantAndEquipment                                         -10495000000  ...          0
# acquisitionsNet                                                                  -624000000  ...          0
# purchasesOfInvestments                                                        -107528000000  ...          0
# salesMaturitiesOfInvestments                                                    98724000000  ...          0
# otherInvestingActivites                                                         65819000000  ...          0
# netCashUsedForInvestingActivites                                                45896000000  ...  -66000000
# debtRepayment                                                                   -8805000000  ...          0
# commonStockIssued                                                                 781000000  ...          0
# commonStockRepurchased                                                         -66116000000  ...   24000000
# dividendsPaid                                                                  -14119000000  ...          0
# otherFinancingActivites                                                         -1936000000  ...          0
# netCashUsedProvidedByFinancingActivities                                       -90976000000  ...   24000000
# effectOfForexChangesOnCash                                                                0  ...          0
# netChangeInCash                                                                 24311000000  ...  222000000
# cashAtEndOfPeriod                                                               50224000000  ...  337000000
# cashAtBeginningOfPeriod                                                         25913000000  ...  115000000
# operatingCashFlow                                                               69391000000  ...  265000000
# capitalExpenditure                                                             -10495000000  ...  -54000000
# freeCashFlow                                                                    58896000000  ...  211000000
# link                                      https://www.sec.gov/Archives/edgar/data/320193...  ...       None
# finalLink                                 https://www.sec.gov/Archives/edgar/data/320193...  ...       None
#
# [35 rows x 35 columns]

# %%
#ahora lo vemos trimestral.
cash_flow_statement_quarterly = fa.cash_flow_statement(ticker, api_key, period="quarter")
cash_flow_statement_quarterly
# Out:
#                                                                                     2020-06  ...      1989-06
# fillingDate                                                                      2020-07-31  ...         None
# acceptedDate                                                            2020-07-30 19:29:09  ...         None
# period                                                                                   Q3  ...           Q3
# netIncome                                                                       11253000000  ...    293000000
# depreciationAndAmortization                                                      2752000000  ...     85000000
# deferredIncomeTax                                                                 833000000  ...     83000000
# stockBasedCompensation                                                           1698000000  ...            0
# changeInWorkingCapital                                                           -430000000  ...    -36000000
# accountsReceivables                                                             -2135000000  ...            0
# inventory                                                                        -689000000  ...            0
# accountsPayables                                                                 2733000000  ...            0
# otherWorkingCapital                                                             44747000000  ...            0
# otherNonCashItems                                                                1863000000  ...        5e+06
# netCashProvidedByOperatingActivities                                            16271000000  ...    429000000
# investmentsInPropertyPlantAndEquipment                                          -1565000000  ...            0
# acquisitionsNet                                                                  -339000000  ...            0
# purchasesOfInvestments                                                         -46072000000  ...            0
# salesMaturitiesOfInvestments                                                    27183000000  ...            0
# otherInvestingActivites                                                         15628000000  ...            0
# netCashUsedForInvestingActivites                                                -5165000000  ...   -605000000
# debtRepayment                                                                   -7379000000  ...            0
# commonStockIssued                                                                         0  ...            0
# commonStockRepurchased                                                         -15891000000  ...     69000000
# dividendsPaid                                                                   -3656000000  ...    -37000000
# otherFinancingActivites                                                          7810000000  ...            0
# netCashUsedProvidedByFinancingActivities                                       -19116000000  ...    -30000000
# effectOfForexChangesOnCash                                                                0  ...            0
# netChangeInCash                                                                 -8010000000  ...   -206000000
# cashAtEndOfPeriod                                                               32164000000  ...  39968000000
# cashAtBeginningOfPeriod                                                         40174000000  ...  40174000000
# operatingCashFlow                                                               16271000000  ...    429000000
# capitalExpenditure                                                              -1565000000  ...   -179000000
# freeCashFlow                                                                    14706000000  ...    250000000
# link                                      https://www.sec.gov/Archives/edgar/data/320193...  ...         None
# finalLink                                 https://www.sec.gov/Archives/edgar/data/320193...  ...         None
#
# [35 rows x 125 columns]

# %%
# Mostrar métricas clave.
key_metrics_annually = fa.key_metrics(ticker, api_key, period="annual")
key_metrics_annually
# Out:
#                                                 2019  ...          1985
# revenuePerShare                         1.399112e+01  ...  1.383439e-01
# netIncomePerShare                       2.971447e+00  ...  4.399885e-03
# operatingCashFlowPerShare               3.731571e+00  ...  1.911425e-02
# freeCashFlowPerShare                    3.167192e+00  ...  1.521927e-02
# cashPerShare                            2.626636e+00  ...  2.430756e-02
# bookValuePerShare                       4.866084e+00  ...  3.967109e-02
# tangibleBookValuePerShare               1.820404e+01  ...  6.751298e-02
# shareholdersEquityPerShare              4.866084e+00  ...  3.967109e-02
# interestDebtPerShare                    5.450898e+00  ...  0.000000e+00
# marketCap                               1.157812e+12  ...  1.114069e+09
# enterpriseValue                         1.206755e+12  ...  7.770694e+08
# peRatio                                 2.095359e+01  ...  1.826343e+01
# priceToSalesRatio                       4.450144e+00  ...  5.808496e-01
# pocfratio                               1.668533e+01  ...  4.204036e+00
# pfcfRatio                               1.965858e+01  ...  5.279950e+00
# pbRatio                                 1.279520e+01  ...  2.025581e+00
# ptbRatio                                1.279520e+01  ...  2.025581e+00
# evToSales                               4.638261e+00  ...  4.051457e-01
# enterpriseValueOverEBITDA               1.474169e+01  ...  4.796725e+00
# evToOperatingCashFlow                   1.739065e+01  ...  2.932338e+00
# evToFreeCashFlow                        2.048959e+01  ...  3.682794e+00
# earningsYield                           4.772451e-02  ...  5.475422e-02
# freeCashFlowYield                       5.086837e-02  ...  1.893957e-01
# debtToEquity                            2.741004e+00  ...  7.018182e-01
# debtToAssets                            7.326921e-01  ...  4.123932e-01
# netDebtToEBITDA                         5.978866e-01  ... -2.080247e+00
# currentRatio                            1.540126e+00  ...  2.786441e+00
# interestCoverage                        1.838283e+01  ...           NaN
# incomeQuality                           1.255809e+00  ...  4.344262e+00
# dividendYield                           1.219456e-02  ...           NaN
# payoutRatio                             2.555198e-01  ...  0.000000e+00
# salesGeneralAndAdministrativeToRevenue  0.000000e+00  ...  0.000000e+00
# researchAndDdevelopementToRevenue       6.233136e-02  ...  3.806048e-02
# intangiblesToTotalAssets                0.000000e+00  ...  0.000000e+00
# capexToOperatingCashFlow               -6.611815e+00  ... -4.907407e+00
# capexToRevenue                         -2.479028e+01  ... -3.551852e+01
# capexToDepreciation                    -1.195522e+00  ... -7.777778e-01
# stockBasedCompensationToRevenue         2.332285e-02  ...  0.000000e+00
# grahamNumber                            1.803703e+01  ...  6.266845e-02
# roic                                    2.823779e-01  ...  1.872075e-01
# returnOnTangibleAssets                  1.632301e-01  ...  6.517094e-02
# grahamNetNet                           -5.972633e+00  ...  1.438979e-02
# workingCapital                          5.710100e+10  ...  5.270000e+08
# tangibleAssetValue                               NaN  ...           NaN
# netCurrentAssetValue                   -8.520900e+10  ...  4.360000e+08
# investedCapital                                  NaN  ...           NaN
# averageReceivables                      4.739950e+10  ...  2.460750e+10
# averagePayables                         5.106200e+10  ...  2.798150e+10
# averageInventory                        4.031000e+09  ...  2.061500e+09
# daysSalesOutstanding                    6.425877e+01  ...  4.186653e+01
# daysPayablesOutstanding                 1.043141e+02  ...  2.448569e+01
# daysOfInventoryOnHand                   9.263639e+00  ...  5.452147e+01
# receivablesTurnover                     5.680159e+00  ...  8.718182e+00
# payablesTurnover                        3.499048e+00  ...  1.490667e+01
# inventoryTurnover                       3.940136e+01  ...  6.694611e+00
# roe                                     6.106445e-01  ...  1.109091e-01
# capexPerShare                          -5.643792e-01  ... -3.894980e-03
#
# [57 rows x 35 columns]

# %%
#ahora lo vemos trimestral
key_metrics_quarterly = fa.key_metrics(ticker, api_key, period="quarter")
key_metrics_quarterly
# Out:
#                                              2020-06  ...       1989-09
# revenuePerShare                         3.426401e+00  ...  9.513335e-02
# netIncomePerShare                       6.460131e-01  ...  1.106681e-02
# operatingCashFlowPerShare               9.340868e-01  ...  5.361562e-03
# freeCashFlowPerShare                    8.442432e-01  ...  1.237283e-03
# cashPerShare                            1.916454e+00  ...  3.010723e-02
# bookValuePerShare                       4.149571e+00  ...  1.021446e-01
# tangibleBookValuePerShare               1.821811e+01  ...  1.886170e-01
# shareholdersEquityPerShare              4.149571e+00  ...  1.021446e-01
# interestDebtPerShare                    6.116314e+00  ...  3.918064e-03
# marketCap                               1.539984e+12  ...  5.780226e+09
# enterpriseValue                         1.612445e+12  ...  5.399226e+09
# peRatio                                 1.368509e+02  ...  3.590202e+01
# priceToSalesRatio                       2.580185e+01  ...  4.176464e+00
# pocfratio                               9.464592e+01  ...  7.410546e+01
# pfcfRatio                               1.047181e+02  ...  3.211237e+02
# pbRatio                                 2.130522e+01  ...  3.889789e+00
# ptbRatio                                2.130522e+01  ...  3.889789e+00
# evToSales                               2.701591e+01  ...  3.901175e+00
# enterpriseValueOverEBITDA               9.721721e+01  ...  1.776061e+01
# evToOperatingCashFlow                   9.909930e+01  ...  6.922084e+01
# evToFreeCashFlow                        1.096454e+02  ...  2.999570e+02
# earningsYield                           7.307220e-03  ...  2.785358e-02
# freeCashFlowYield                       9.549452e-03  ...  3.114065e-03
# debtToEquity                            3.390360e+00  ...  8.465680e-01
# debtToAssets                            7.722282e-01  ...  4.584548e-01
# netDebtToEBITDA                         4.368805e+00  ... -1.253289e+00
# currentRatio                            1.469450e+00  ...  2.563128e+00
# interestCoverage                        1.884792e+01  ...           NaN
# incomeQuality                           1.445926e+00  ...  4.844720e-01
# dividendYield                           2.374051e-03  ...  2.249047e-03
# payoutRatio                             3.248911e-01  ...  8.074534e-02
# salesGeneralAndAdministrativeToRevenue  0.000000e+00  ...  0.000000e+00
# researchAndDdevelopementToRevenue       7.971852e-02  ...  8.164740e-02
# intangiblesToTotalAssets                0.000000e+00  ...  0.000000e+00
# capexToOperatingCashFlow               -1.039681e+01  ... -1.300000e+00
# capexToRevenue                         -3.813738e+01  ... -2.306667e+01
# capexToDepreciation                    -1.758466e+00  ... -6.666667e-01
# stockBasedCompensationToRevenue         2.844936e-02  ...  0.000000e+00
# grahamNumber                            7.766288e+00  ...  1.594815e-01
# roic                                    5.916875e-02  ...  1.427799e-01
# returnOnTangibleAssets                  3.545994e-02  ...  5.867347e-02
# grahamNetNet                           -7.232944e+00  ...  2.634383e-02
# workingCapital                          4.474700e+10  ...  1.399000e+09
# tangibleAssetValue                               NaN  ...           NaN
# netCurrentAssetValue                   -1.049970e+11  ...  1.036000e+09
# investedCapital                                  NaN  ...           NaN
# averageReceivables                      3.137600e+10  ...  1.573500e+10
# averagePayables                         3.387300e+10  ...  1.637750e+10
# averageInventory                        3.656000e+09  ...  1.904500e+09
# daysSalesOutstanding                    4.836642e+01  ...  5.156792e+01
# daysPayablesOutstanding                 8.591407e+01  ...  4.440177e+01
# daysOfInventoryOnHand                   9.674909e+00  ...  6.314623e+01
# receivablesTurnover                     1.860795e+00  ...  1.745271e+00
# payablesTurnover                        1.047558e+00  ...  2.026946e+00
# inventoryTurnover                       9.302413e+00  ...  1.425263e+00
# roe                                     1.556819e-01  ...  1.083445e-01
# capexPerShare                          -8.984364e-02  ... -4.124278e-03
#
# [57 rows x 124 columns]

# %%
# Mostrar un gran conjunto de ratios en profundidad
financial_ratios_annually = fa.financial_ratios(ticker, api_key, period="annual")
financial_ratios_annually
# Out:
#                                           2019  ...       1985
# currentRatio                          1.540126  ...   2.786441
# quickRatio                            1.384447  ...   1.888136
# cashRatio                             0.462022  ...   1.142373
# daysOfSalesOutstanding               64.258765  ...  41.866528
# daysOfInventoryOutstanding            9.263639  ...  54.521467
# operatingCycle                       73.522404  ...  96.387995
# daysOfPayablesOutstanding           104.314077  ...  24.485689
# cashConversionCycle                 -30.791673  ...  71.902306
# grossProfitMargin                     0.378178  ...   0.417101
# operatingProfitMargin                 0.245720  ...   0.053702
# pretaxProfitMargin                    0.252666  ...   0.062565
# netProfitMargin                       0.212381  ...   0.031804
# effectiveTaxRate                      0.159438  ...   0.491667
# returnOnAssets                        0.163230  ...   0.065171
# returnOnEquity                        0.610645  ...   0.110909
# returnOnCapitalEmployed               0.282378  ...   0.187207
# netIncomePerEBT                       0.840562  ...   0.508333
# ebtPerEbit                            1.000000  ...   1.000000
# ebitPerRevenue                        0.252666  ...   0.062565
# debtRatio                             0.732692  ...   0.412393
# debtEquityRatio                       2.741004  ...   0.701818
# longTermDebtToCapitalization          0.503618  ...        NaN
# totalDebtToCapitalization             0.519384  ...        NaN
# interestCoverage                     18.382830  ...        NaN
# cashFlowToDebtRatio                   0.709614  ...        NaN
# companyEquityMultiplier               3.741004  ...   1.701818
# receivablesTurnover                   5.680159  ...   8.718182
# payablesTurnover                      3.499048  ...  14.906667
# inventoryTurnover                    39.401364  ...   6.694611
# fixedAssetTurnover                    6.960619  ...  21.311111
# assetTurnover                         0.768572  ...   2.049145
# operatingCashFlowPerShare             3.731571  ...   0.019114
# freeCashFlowPerShare                  3.167192  ...   0.015219
# cashPerShare                          5.407554  ...   0.024308
# payoutRatio                           0.255520  ...   0.000000
# operatingCashFlowSalesRatio           0.266710  ...   0.138165
# freeCashFlowOperatingCashFlowRatio    0.848756  ...   0.796226
# cashFlowCoverageRatios                0.709614  ...        NaN
# shortTermCoverageRatios              11.603846  ...        NaN
# capitalExpenditureCoverageRatio      -6.611815  ...  -4.907407
# dividendPaidAndCapexCoverageRatio    19.147627  ...        NaN
# dividendPayoutRatio                   0.255520  ...        NaN
# priceBookValueRatio                  12.795197  ...   2.025581
# priceToBookRatio                     12.795197  ...   2.025581
# priceToSalesRatio                     4.450144  ...   0.580850
# priceEarningsRatio                   20.953594  ...  18.263434
# priceToFreeCashFlowsRatio            19.658581  ...   5.279950
# priceToOperatingCashFlowsRatio       16.685331  ...   4.204036
# priceCashFlowRatio                   16.685331  ...   4.204036
# priceEarningsToGrowthRatio            6.545258  ...   4.253317
# priceSalesRatio                       4.450144  ...   0.580850
# dividendYield                         0.012195  ...        NaN
# enterpriseValueMultiple              14.741691  ...   4.796725
# priceFairValue                       12.795197  ...   2.025581
#
# [54 rows x 35 columns]

# %%
#ahora lo vemos trimestralmente.
financial_ratios_quarterly = fa.financial_ratios(ticker, api_key, period="quarter")
financial_ratios_quarterly
# Out:
#                                        2020-06  ...     1989-09
# currentRatio                          1.469450  ...    2.563128
# quickRatio                            1.312449  ...    1.789944
# cashRatio                             0.350228  ...    0.489385
# daysOfSalesOutstanding              196.152718  ...  209.136561
# daysOfInventoryOutstanding            9.674909  ...   63.146233
# operatingCycle                       58.041333  ...  114.714152
# daysOfPayablesOutstanding            85.914066  ...   44.401773
# cashConversionCycle                 -27.872733  ...   70.312380
# grossProfitMargin                     0.379995  ...    0.510116
# operatingProfitMargin                 0.219335  ...    0.124277
# pretaxProfitMargin                    0.220106  ...    0.190751
# netProfitMargin                       0.188540  ...    0.116329
# effectiveTaxRate                      0.143412  ...    0.390152
# returnOnAssets                        0.035460  ...    0.058673
# returnOnEquity                        0.155682  ...    0.108345
# returnOnCapitalEmployed               0.059169  ...    0.142780
# netIncomePerEBT                       0.856588  ...    0.609848
# ebtPerEbit                            1.000000  ...    1.000000
# ebitPerRevenue                        0.220106  ...    0.190751
# debtRatio                             0.772228  ...    0.458455
# debtEquityRatio                       3.390360  ...    0.846568
# longTermDebtToCapitalization          0.567070  ...         NaN
# totalDebtToCapitalization             0.594209  ...         NaN
# interestCoverage                     18.847920  ...         NaN
# cashFlowToDebtRatio                   0.153726  ...         NaN
# companyEquityMultiplier               4.390360  ...    1.846568
# receivablesTurnover                   1.860795  ...    1.745271
# payablesTurnover                      1.047558  ...    2.026946
# inventoryTurnover                     9.302413  ...    1.425263
# fixedAssetTurnover                    1.361086  ...    4.143713
# assetTurnover                         0.188077  ...    0.504373
# operatingCashFlowPerShare             0.934087  ...    0.005362
# freeCashFlowPerShare                  0.844243  ...    0.001237
# cashPerShare                          5.340386  ...    0.055609
# payoutRatio                           0.324891  ...    0.080745
# operatingCashFlowSalesRatio           0.272615  ...    0.056358
# freeCashFlowOperatingCashFlowRatio    0.903817  ...    0.230769
# cashFlowCoverageRatios                0.153726  ...         NaN
# shortTermCoverageRatios               1.457191  ...    1.368421
# capitalExpenditureCoverageRatio     -10.396805  ...   -1.300000
# dividendPaidAndCapexCoverageRatio     7.781444  ...   -1.659574
# dividendPayoutRatio                   0.324891  ...    0.080745
# priceBookValueRatio                  21.305217  ...    3.889789
# priceToBookRatio                     21.305217  ...    3.889789
# priceToSalesRatio                    25.801855  ...    4.176464
# priceEarningsRatio                  136.850946  ...   35.902024
# priceToFreeCashFlowsRatio           104.718054  ...  321.123662
# priceToOperatingCashFlowsRatio       94.645916  ...   74.105460
# priceCashFlowRatio                   94.645916  ...   74.105460
# priceEarningsToGrowthRatio          211.914609  ...   46.431029
# priceSalesRatio                      25.801855  ...    4.176464
# dividendYield                         0.002374  ...    0.002249
# enterpriseValueMultiple              97.217213  ...   17.760612
# priceFairValue                       21.305217  ...    3.889789
#
# [54 rows x 124 columns]

# %%
# Mostrar el crecimiento de la compañía.
growth_annually = fa.financial_statement_growth(ticker, api_key, period="annual")
growth_annually
# Out:
#                                             2019       2018  ...      1984  1983
# revenueGrowth                          -0.020411   0.158620  ...  0.542218     0
# grossProfitGrowth                      -0.033848   0.154820  ...  0.335430     0
# ebitgrowth                             -0.098282   0.155745  ... -0.338462     0
# operatingIncomeGrowth                  -0.098282   0.155745  ... -0.338462     0
# netIncomeGrowth                        -0.071811   0.231226  ... -0.168831     0
# epsgrowth                              -0.001693   0.293176  ... -0.182927     0
# epsdilutedGrowth                       -0.001693   0.293176  ... -0.182927     0
# weightedAverageSharesGrowth            -0.070238  -0.047905  ...  0.017000     0
# weightedAverageSharesDilutedGrowth     -0.070238  -0.047905  ...  0.017000     0
# dividendsperShareGrowth                 0.107468   0.127882  ...  0.000000     0
# operatingCashFlowGrowth                -0.103869   0.205668  ...  0.000000     0
# freeCashFlowGrowth                     -0.081487   0.238479  ...  0.000000     0
# tenYRevenueGrowthPerShare               7.281517   9.327879  ...  0.516439     0
# fiveYRevenueGrowthPerShare              0.874616   1.027000  ...  0.516439     0
# threeYRevenueGrowthPerShare             0.427480   0.316626  ...  0.516439     0
# tenYOperatingCFGrowthPerShare           8.328377   9.191435  ...  0.000000     0
# fiveYOperatingCFGrowthPerShare          0.530548   0.882061  ...  0.000000     0
# threeYOperatingCFGrowthPerShare         0.239582   0.103957  ...  0.000000     0
# tenYNetIncomeGrowthPerShare             8.163676  14.553582  ... -0.182725     0
# fiveYNetIncomeGrowthPerShare            0.841981   1.096567  ... -0.182725     0
# threeYNetIncomeGrowthPerShare           0.430936   0.291754  ... -0.182725     0
# tenYShareholdersEquityGrowthPerShare    2.905786   5.434794  ...  0.209596     0
# fiveYShareholdersEquityGrowthPerShare   0.068430   0.131207  ...  0.209596     0
# threeYShareholdersEquityGrowthPerShare -0.165223   0.040085  ...  0.209596     0
# tenYDividendperShareGrowthPerShare      0.000000   0.000000  ...  0.000000     0
# fiveYDividendperShareGrowthPerShare     0.671390   0.693065  ...  0.000000     0
# threeYDividendperShareGrowthPerShare    0.374868   0.374152  ...  0.000000     0
# receivablesGrowth                      -0.065129   0.373448  ...  0.897059     0
# inventoryGrowth                         0.037917  -0.185170  ...  0.866197     0
# assetGrowth                            -0.074397  -0.025562  ...  0.416517     0
# bookValueperShareGrowth                 0.000000   0.000000  ...  0.000000     0
# debtGrowth                             -0.056218  -0.010348  ... -1.000000     0
# rdexpenseGrowth                         0.139154   0.229255  ...  0.183333     0
# sgaexpensesGrowth                       0.092188   0.094620  ...  0.672474     0
#
# [34 rows x 37 columns]

# %%
#ahora lo vemos trimestral.
growth_quarterly = fa.financial_statement_growth(ticker, api_key, period="quarter")
growth_quarterly
# Out:
#                                          2020-06   2020-03  ...    1989-12   1989-09
# revenueGrowth                           0.023528 -0.364914  ...   0.078757  0.108974
# grossProfitGrowth                       0.013858 -0.364795  ...   0.100567  0.144246
# ebitgrowth                              0.018517 -0.497321  ...   0.104651  0.146667
# operatingIncomeGrowth                   0.018517 -0.497321  ...   0.104651  0.146667
# netIncomeGrowth                         0.000356 -0.494109  ...  -0.223602  0.677083
# epsgrowth                               0.011809 -0.488373  ...  -0.221319  0.669683
# epsdilutedGrowth                        0.011809 -0.488373  ...  -0.221319  0.669683
# weightedAverageSharesGrowth            -0.011330 -0.011205  ...  -0.003024  0.004696
# weightedAverageSharesDilutedGrowth     -0.011330 -0.011205  ...  -0.003024  0.004696
# dividendsperShareGrowth                 0.095673 -0.035534  ...   0.080190 -0.650291
# operatingCashFlowGrowth                 0.222372 -0.563803  ...   2.346154 -0.818182
# freeCashFlowGrowth                      0.283470 -0.596677  ...  10.000000 -0.928000
# tenYRevenueGrowthPerShare               4.667311  5.335499  ...   0.082030  0.000000
# fiveYRevenueGrowthPerShare              0.595050  0.331643  ...   0.082030  0.000000
# threeYRevenueGrowthPerShare             0.579489  0.316976  ...   0.082030  0.000000
# tenYOperatingCFGrowthPerShare           4.052357  7.378607  ...   2.356305  0.000000
# fiveYOperatingCFGrowthPerShare          0.439147 -0.075866  ...   2.356305  0.000000
# threeYOperatingCFGrowthPerShare         1.402593  0.265059  ...   2.356305  0.000000
# tenYNetIncomeGrowthPerShare             4.156984  4.366945  ...  -0.221247  0.000000
# fiveYNetIncomeGrowthPerShare            0.397184  0.098225  ...  -0.221247  0.000000
# threeYNetIncomeGrowthPerShare           0.551261  0.218465  ...  -0.221247  0.000000
# tenYShareholdersEquityGrowthPerShare    1.499502  1.923135  ...   0.028683  0.000000
# fiveYShareholdersEquityGrowthPerShare  -0.237554 -0.194677  ...   0.028683  0.000000
# threeYShareholdersEquityGrowthPerShare -0.344091 -0.301254  ...   0.028683  0.000000
# tenYDividendperShareGrowthPerShare      0.000000  0.000000  ...   0.080190  0.000000
# fiveYDividendperShareGrowthPerShare     0.587501  0.629947  ...   0.080190  0.000000
# threeYDividendperShareGrowthPerShare    0.305584  0.342175  ...   0.080190  0.000000
# receivablesGrowth                       0.045572 -0.232038  ...  -0.055485  0.000000
# inventoryGrowth                         0.193161 -0.186234  ...  -0.101053  0.000000
# assetGrowth                            -0.009538 -0.059357  ...   0.025146  0.000000
# bookValueperShareGrowth                 0.000000  0.000000  ...   0.000000  0.000000
# debtGrowth                              0.029213  0.011218  ...   0.192982  0.000000
# rdexpenseGrowth                         0.042278  0.025612  ...  -0.061947  0.097087
# sgaexpensesGrowth                      -0.024435 -0.047143  ...   0.139810  0.162534
#
# [34 rows x 124 columns]

# %%
# Descargar datos generales de la empresa.
stock_data = fa.stock_data(ticker, period="ytd", interval="1d")
stock_data
# Out:
#                   high       close  ...     volume    adjclose
# 2020-01-02   75.150002   75.087502  ...  135480400   74.573036
# 2020-01-03   75.144997   74.357498  ...  146322800   73.848030
# 2020-01-06   74.989998   74.949997  ...  118387200   74.436470
# 2020-01-07   75.224998   74.597504  ...  108872000   74.086395
# 2020-01-08   76.110001   75.797501  ...  132079200   75.278160
# ...                ...         ...  ...        ...         ...
# 2020-10-12  125.180000  124.400002  ...  240226800  124.400002
# 2020-10-13  125.389999  121.099998  ...  262330500  121.099998
# 2020-10-14  123.029999  121.190002  ...  151062300  121.190002
# 2020-10-15  121.199997  120.709999  ...  112224600  120.709999
# 2020-10-16  121.540001  119.800003  ...   56914841  119.800003
#
# [201 rows x 6 columns]

# %%
# Descargar datos detallados de la empresa.
stock_data_detailed = fa.stock_data_detailed(ticker, api_key, begin="2000-10-01", end="2020-10-16")
stock_data_detailed
# Out:
#                 open      high  ...           label changeOverTime
# 2020-10-15    118.72     121.2  ...  October 15, 20        0.01676
# 2020-10-14       121    123.03  ...  October 14, 20        0.00157
# 2020-10-13    125.27    125.39  ...  October 13, 20       -0.03329
# 2020-10-12    120.06    125.18  ...  October 12, 20        0.03615
# 2020-10-09    115.28       117  ...  October 09, 20        0.01466
# ...              ...       ...  ...             ...            ...
# 2000-10-06  0.405134  0.409598  ...  October 06, 00       -0.02204
# 2000-10-05  0.419643    0.4375  ...  October 05, 00       -0.06117
# 2000-10-04  0.399554  0.424107  ...  October 04, 00        0.05586
# 2000-10-03  0.445313  0.446429  ...  October 03, 00       -0.10527
# 2000-10-02  0.476563  0.477679  ...  October 02, 00       -0.09134
#
# [5042 rows x 12 columns]

# %% [markdown]
# Con estos datos se puede hacer un análisis completo de la empresa seleccionada, en este caso Apple. Sin embargo, al recorrer una gran selección de empresas, puede recopilar una gran cantidad de datos. Por lo tanto, al entrar en un sector específico (por ejemplo, todos los tickers de la industria Semi-Conducter) puede cuantificar rápidamente el sector y buscar datos clave.
#
# Para encontrar empresas pertenecientes a un sector o sector específico, por favor eche un vistazo a los archivos JSON [aquí](https://github.com/JerBouma/FundamentalsQuantifier/tree/master/data). Alternativamente, puede echar un vistazo a los Fundamentos Quantifier, un sitio web que he escrito para comparar visualmente cualquier selección de empresas.
